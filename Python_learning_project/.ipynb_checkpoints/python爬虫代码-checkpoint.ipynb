# %%
import requests
from bs4 import BeautifulSoup
res =requests.get('http://news.sina.com.cn/o/2018-06-25/doc-ihencxtt9123070.shtml')
res.encoding='utf-8'
soup =BeautifulSoup(res.text,'html.parser')
#soup.select('.source')[0].text
dt =soup.select('.date')[0].contents[0].strip()
type(dt)
# Out:
# str

# %%
from datetime import datetime
dd=datetime.strptime(dt,'%Y年%m月%d日 %H:%M')
type(dd)
# Out:
# datetime.datetime

# %%
import requests
comments =requests.get('http://comment5.news.sina.com.cn/page/info?version=1&format=json&channel=gn&newsid=comos-hencxtt9123070&group=undefined&compress=0&ie=utf-8&oe=utf-8&page=1&page_size=3')
#print(comments.text)
import json
jd = json.loads(comments.text)
jd['result']['count']['total']
# Out:
# 2930

# %%
newsurl ='http://news.sina.com.cn/o/2018-06-25/doc-ihencxtt9123070.shtml'
newsid = newsurl.split('/')[-1].rstrip('.shtml').lstrip('doc-i')
#newsid

# %%
import re
m = re.search('doc-i(.+).shtml',newsurl)
newsid = m.group(1)
print(newsid)
# Out:
# hencxtt9123070

# %%
commentURL ='http://comment5.news.sina.com.cn/page/info?version=1&format=json&channel=gn&newsid=comos-{}&group=undefined&compress=0&ie=utf-8&oe=utf-8&page=1&page_size=3&t_size=3&h_size=3'
commentURL.format(newsid)
# Out:
# 'http://comment5.news.sina.com.cn/page/info?version=1&format=json&channel=gn&newsid=comos-hencxtt9123070&group=undefined&compress=0&ie=utf-8&oe=utf-8&page=1&page_size=3&t_size=3&h_size=3'

# %%
#取得评论数，新闻id，评论并写成统一函式
import re
import json
def getCommentCounts(newsurl):
    m = re.search('doc-i(.+).shtml',newsurl)
    newsid = m.group(1)
    comments =requests.get(commentURL.format(newsid))
    print(comments)
    jd = json.loads(comments.text)
    return jd['result']['count']['total']

# %%
news ='http://news.sina.com.cn/o/2018-06-25/doc-ihencxtt9123070.shtml'

getCommentCounts(news)
# Out:
# <Response [200]>
# 2930

# %%
import requests
from datetime import datetime
from bs4 import BeautifulSoup
def getNewsDetail(newsurl):
    result={}
    res = requests.get(newsurl)
    res.encoding ='utf-8'
    soup =BeautifulSoup(res.text,'html.parser')
    result['title']=soup.select('.main-title')[0].text
    result['newssource']=soup.select('.source')[0].text
    timesource = soup.select('.date')[0].contents[0].strip()
    result['dt']= datetime.strptime(timesource,'%Y年%m月%d日 %H:%M')
    result['article']= ' '.join([p.text.strip() for p in soup.select('#artibody p')[:-1]])
    result['editor'] = soup.select('.show_author')[0].text.strip('责任编辑：')
    result['comments'] = getCommentCounts(newsurl)
    return result

# %%
getNewsDetail('http://news.sina.com.cn/o/2018-06-25/doc-ihencxtt9123070.shtml')
# Out:
# <Response [200]>
# {'title': '美国放风限制中企投资 外交部回应',
#  'newssource': '外交部网站',
#  'dt': datetime.datetime(2018, 6, 25, 17, 52),
#  'article': '',
#  'editor': '张迪 ',
#  'comments': 2930}

# %%
import requests
import json
res =requests.get('http://api.roll.news.sina.com.cn/zt_list?channel=news&cat_1=gnxw&cat_2==gdxw1||=gatxw||=zs-pl||=mtjj&level==1||=2&show_ext=1&show_all=1&show_num=22&tag=1&format=json&page=2&callback=newsloadercallback&_=1530023877286')
jd= json.loads(res.text.lstrip('  newsloadercallback(').rstrip(');'))
jd
# Out:
# {'result': {'status': {'code': '0'},
#   'encoding': 'utf-8',
#   'serverSeconds': '1531724208',
#   'total': '481727',
#   'count': '22',
#   'last_time': '1531494234',
#   'data': [{'id': '1-1-35971531',
#     'column': 'gdxw1',
#     'title': '资深机长：抽烟不是新闻 误关空调让同行笑掉大牙',
#     'url': 'http://news.sina.com.cn/c/nd/2018-07-13/doc-ihfhfwmv0249311.shtml',
#     'keywords': '机长,烟感,动车,电子烟,空调',
#     'comment_channel': 'gn',
#     'img': '',
#     'level': '1',
#     'createtime': '1531494234',
#     'ext1': '',
#     'ext2': 'gn:comos-hfhfwmv0249311:0',
#     'ext3': '',
#     'ext4': 'gn:comos-hfhfwmv0249311:0',
#     'ext5': '原标题：资深机长：飞行员抽烟不是新闻，“误关空调”让同行笑掉大牙\n来源：长江日报',
#     'old_level': '1',
#     'media_type': '',
#     'media_name': '新浪新闻综合'},
#    {'id': '1-1-35971514',
#     'column': 'gdxw1',
#     'title': '广州高校一对夫妻教员被同事杀死 嫌疑人被批捕',
#     'url': 'http://news.sina.com.cn/o/2018-07-13/doc-ihfhfwmv0226415.shtml',
#     'keywords': '嫌疑人,广州大学城,检方',
#     'comment_channel': '',
#     'img': '',
#     'level': '1',
#     'createtime': '1531493912',
#     'ext1': '',
#     'ext2': 'gn:comos-hfhfwmv0226415:0',
#     'ext3': '',
#     'ext4': 'gn:comos-hfhfwmv0226415:0',
#     'ext5': '原标题：“6.29”广州大学城故意杀人案嫌疑人被检方批捕\n中新网广州7月13日电 （记者 程景伟）据广州市番禺区人民检察院13日通报，当日，该院以涉嫌故意杀人罪对引起社会广泛关注的“6.29”广州大学城故意杀人案犯罪嫌疑人谢冬青依法作出批准逮捕决定。',
#     'old_level': '1',
#     'media_type': '',
#     'media_name': '中国新闻网'},
#    {'id': '1-1-35971377',
#     'column': 'gatxw',
#     'title': '蔡英文出行抗议随处见 台年轻人:我们的未来在哪?',
#     'url': 'http://news.sina.com.cn/c/gat/2018-07-13/doc-ihfhfwmu9092604.shtml',
#     'keywords': '蔡英文,台南,高思博',
#     'comment_channel': 'gn',
#     'img': '',
#     'level': '0',
#     'createtime': '1531480311',
#     'ext1': '',
#     'ext2': 'gn:comos-hfhfwmu9092604:0',
#     'ext3': '',
#     'ext4': 'gn:comos-hfhfwmu9092604:0',
#     'ext5': '原标题：蔡英文出行抗议随处可见 年轻人：我们的未来在哪里\n中评社7月13日报道，台湾地区领导人蔡英文13日走访台南四个行程，都碰到如影随形的抗议。中国国民党台南市长参选人高思博阵营青年军也举牌加入抗议行列，抨击民进党“灭香封炉”违背传统，台南经济越来越萧条，年轻人在台南根本看不到…',
#     'old_level': '2',
#     'media_type': '',
#     'media_name': '观察者网'},
#    {'id': '1-1-35966795',
#     'column': 'gdxw1',
#     'title': '北京市长陈吉宁会见美国特斯拉公司董事长马斯克',
#     'url': 'http://news.sina.com.cn/c/nd/2018-07-13/doc-ihfhfwmu3378104.shtml',
#     'keywords': '陈吉宁,特斯拉,马斯克,市长,范俊生',
#     'comment_channel': 'gn',
#     'img': '',
#     'level': '1',
#     'createtime': '1531434923',
#     'ext1': '',
#     'ext2': 'gn:comos-hfhfwmu3378104:0',
#     'ext3': '',
#     'ext4': 'gn:comos-hfhfwmu3378104:0',
#     'ext5': '原标题：北京市长陈吉宁会见美国特斯拉公司董事长马斯克\n来源：北京日报',
#     'old_level': '1',
#     'media_type': '',
#     'media_name': '新浪新闻综合'},
#    {'id': '1-1-35966597',
#     'column': 'gdxw1',
#     'title': '人民日报望海楼：荒谬的药方治不了美国的病',
#     'url': 'http://news.sina.com.cn/c/nd/2018-07-13/doc-ihfhfwmu3223315.shtml',
#     'keywords': '望海楼,贸易战,美方,调查报告,灯泡',
#     'comment_channel': 'gn',
#     'img': '',
#     'level': '0',
#     'createtime': '1531431313',
#     'ext1': '',
#     'ext2': 'gn:comos-hfhfwmu3223315:0',
#     'ext3': '',
#     'ext4': 'gn:comos-hfhfwmu3223315:0',
#     'ext5': '近日，美方突然公布了拟对价值2000亿美元从中国进口商品加征关税清单，使贸易战加速升级。这是一种显然会伤害中美双边贸易，并将危害世界经济的挑衅行为，我们不禁要问：美方采取如此蛮横举措，道理何在？\n几位美国高官近日倒也在不断重复一套说辞，声称美国在对华贸易中受到了“不公平待遇”：…',
#     'old_level': '2',
#     'media_type': '',
#     'media_name': '人民日报海外版'},
#    {'id': '1-1-35966475',
#     'column': 'gdxw1',
#     'title': '中国商务部突然发的这篇声明 传递了一个核心信息',
#     'url': 'http://news.sina.com.cn/c/nd/2018-07-13/doc-ihfhfwmu3154606.shtml',
#     'keywords': '贸易战,世贸组织,美方,中方,国内法',
#     'comment_channel': 'gn',
#     'img': '',
#     'level': '1',
#     'createtime': '1531429588',
#     'ext1': '',
#     'ext2': 'gn:comos-hfhfwmu3154606:0',
#     'ext3': '',
#     'ext4': 'gn:comos-hfhfwmu3154606:0',
#     'ext5': '原标题：中国商务部突然发的这篇声明，传递了一个核心信息！\n来源：牛弹琴',
#     'old_level': '1',
#     'media_type': '',
#     'media_name': '新浪新闻综合'},
#    {'id': '1-1-35966295',
#     'column': 'gdxw1',
#     'title': '黑龙江省长谈小煤矿整治:是干部忠诚担当的试金石',
#     'url': 'http://news.sina.com.cn/c/2018-07-13/doc-ihfhfwmu2974994.shtml',
#     'keywords': '煤矿,供暖,声音',
#     'comment_channel': 'gn',
#     'img': '',
#     'level': '1',
#     'createtime': '1531425202',
#     'ext1': '',
#     'ext2': 'gn:comos-hfhfwmu2974994:0',
#     'ext3': '',
#     'ext4': 'gn:comos-hfhfwmu2974994:0',
#     'ext5': '原标题：闯过整治小煤矿这道“坎”（声音）\n把小煤矿专项整治作为对我们是否筑牢“四个意识”的一次检验，作为干部是否忠诚、干净、担当的试金石',
#     'old_level': '1',
#     'media_type': '',
#     'media_name': '人民日报'},
#    {'id': '1-1-35966075',
#     'column': 'zs-pl',
#     'title': '新京报谈教授兼职被控贪污案反转:重公正而非成就',
#     'url': 'http://news.sina.com.cn/c/zs/2018-07-13/doc-ihfhfwmu2606271.shtml',
#     'keywords': '贪污案,科研人员,兼职',
#     'comment_channel': 'gn',
#     'img': '',
#     'level': '0',
#     'createtime': '1531417171',
#     'ext1': '',
#     'ext2': 'gn:comos-hfhfwmu2606271:0',
#     'ext3': '',
#     'ext4': 'gn:comos-hfhfwmu2606271:0',
#     'ext5': '原标题：教授兼职被控贪污案反转： 重公正而非成就\n在娄高明案件的背后，除了司法的人性化之外，科研经费使用、报销、管理，科研人员兼职的规范、取酬及利益保障，更应人性化。',
#     'old_level': '2',
#     'media_type': '',
#     'media_name': '新京报'},
#    {'id': '1-1-35965989',
#     'column': 'gdxw1',
#     'title': '驻韩美军将用以干预南海?美探索半岛驻军任务转型',
#     'url': 'http://news.sina.com.cn/o/2018-07-13/doc-ihfefkqr3688372.shtml',
#     'keywords': '半岛,驻韩美军,南海',
#     'comment_channel': '',
#     'img': '',
#     'level': '1',
#     'createtime': '1531414494',
#     'ext1': '',
#     'ext2': 'gn:comos-hfefkqr3688372:0',
#     'ext3': '',
#     'ext4': 'gn:comos-hfefkqr3688372:0',
#     'ext5': '原标题：驻韩美军将用以干预南海？美军探索半岛驻军任务转型\n据韩联社7月3日报道称，在60多年前将其总部坐落于首尔市中心时，驻韩美军在冷战高潮时面临着冷酷的现实：受战争蹂躏的韩国认为自己处于很高的安全风险中。',
#     'old_level': '1',
#     'media_type': '',
#     'media_name': '参考消息'},
#    {'id': '1-1-35965981',
#     'column': 'gdxw1',
#     'title': '有力回击美国政府的不实指控 商务部可以这样做',
#     'url': 'http://news.sina.com.cn/c/nd/2018-07-13/doc-ihfefkqr3653800.shtml',
#     'keywords': '纳瓦罗,贸易战,美方,姆努钦,美国媒体',
#     'comment_channel': 'gn',
#     'img': '',
#     'level': '1',
#     'createtime': '1531413961',
#     'ext1': '',
#     'ext2': 'gn:comos-hfefkqr3653800:0',
#     'ext3': '',
#     'ext4': 'gn:comos-hfefkqr3653800:0',
#     'ext5': '原标题：有力回击美国政府的不实指控，商务部可以这样做！\n就在几个小时前，针对美国政府给出的对中国发动贸易战的一系列理由，我商务部也出台了一个详细的声明，逐条批驳了美方的观点。',
#     'old_level': '1',
#     'media_type': '',
#     'media_name': '环球网'},
#    {'id': '1-1-35965904',
#     'column': 'gdxw1',
#     'title': '英媒：马来西亚高官或本周访华 重谈四大项目合同',
#     'url': 'http://news.sina.com.cn/w/2018-07-13/doc-ihfefkqr3593981.shtml',
#     'keywords': '马来西亚,访华,四大',
#     'comment_channel': 'gj',
#     'img': '',
#     'level': '1',
#     'createtime': '1531413079',
#     'ext1': '',
#     'ext2': 'gn:comos-hfefkqr3593981:0',
#     'ext3': '',
#     'ext4': 'gn:comos-hfefkqr3593981:0',
#     'ext5': '原标题：英媒：马来西亚高官或本周访华 重谈四大项目合同\n参考消息网7月13日报道 英媒称，自5月令人咋舌的大选结果公布之后，马来西亚就对其外交政策进行了大幅调整，并改变了对基础设施项目的态度。',
#     'old_level': '1',
#     'media_type': '',
#     'media_name': '参考消息'},
#    {'id': '1-1-35965901',
#     'column': 'gdxw1',
#     'title': '“老肉”回锅胜算高？外媒称台地方选举机关算尽',
#     'url': 'http://news.sina.com.cn/o/2018-07-13/doc-ihfefkqr3570287.shtml',
#     'keywords': '选举,苏贞昌,胜算',
#     'comment_channel': '',
#     'img': '',
#     'level': '1',
#     'createtime': '1531412750',
#     'ext1': '',
#     'ext2': 'gn:comos-hfefkqr3570287:0',
#     'ext3': '',
#     'ext4': 'gn:comos-hfefkqr3570287:0',
#     'ext5': '原标题：“老肉”回锅胜算高？外媒称台湾地方选举“机关算尽”\n参考消息网7月13日报道 还有不到五个月，台湾将举行“九合一”地方公职人员选举，当中尤以县市长选战备受瞩目。随着蓝绿地方首长人选大致底定，令人玩味的选举现象也开始浮现，新加坡媒体总结出此次选战的三大趋势，分析今年的选举…',
#     'old_level': '1',
#     'media_type': '',
#     'media_name': '参考消息'},
#    {'id': '1-1-35965842',
#     'column': 'gdxw1',
#     'title': '人民日报：美国不应将世界经济拖入“衰退陷阱”',
#     'url': 'http://news.sina.com.cn/o/2018-07-12/doc-ihfefkqr3371214.shtml',
#     'keywords': '贸易战,关税,世界经济',
#     'comment_channel': '',
#     'img': '',
#     'level': '0',
#     'createtime': '1531409899',
#     'ext1': '',
#     'ext2': 'gn:comos-hfefkqr3371214:0',
#     'ext3': '',
#     'ext4': 'gn:comos-hfefkqr3371214:0',
#     'ext5': '原标题：美国不应将世界经济拖入“衰退陷阱”\n对世界经济史来说，十年并不是一个很长的时间段。许多人一定还记得，世界经济在美国华尔街引发的国际金融危机中风雨飘摇时，人们喊出的“信心比黄金更重要”这句话饱含了多少焦虑和不安。',
#     'old_level': '2',
#     'media_type': '',
#     'media_name': '人民日报'},
#    {'id': '1-1-35965888',
#     'column': 'gdxw1',
#     'title': '中国病理学泰斗去世 诊断曾被誉为“全国金标准”',
#     'url': 'http://news.sina.com.cn/c/nd/2018-07-13/doc-ihfefkqr2030117.shtml',
#     'keywords': '刘彤华,病理,病理学,病理科',
#     'comment_channel': 'gn',
#     'img': '',
#     'level': '1',
#     'createtime': '1531395048',
#     'ext1': '',
#     'ext2': 'gn:comos-hfefkqr2030117:0',
#     'ext3': '',
#     'ext4': 'gn:comos-hfefkqr2030117:0',
#     'ext5': '原标题：中国病理学泰斗去世，她一辈子都在与死神争夺患者生命\n中国工程院院士，著名医学家、病理学家、医学教育家，北京协和医院病理科教授、研究员刘彤华同志，因病医治无效，于2018年7月8日11时11分在北京协和医院逝世，享年89岁。',
#     'old_level': '1',
#     'media_type': '',
#     'media_name': '人民日报'},
#    {'id': '1-1-35963977',
#     'column': 'gatxw',
#     'title': '英政府:一直以“台湾”称呼台湾 反对航企改标注',
#     'url': 'http://news.sina.com.cn/o/2018-07-12/doc-ihfefkqr0818002.shtml',
#     'keywords': '观察者网,英国航空,称呼',
#     'comment_channel': '',
#     'img': '',
#     'level': '1',
#     'createtime': '1531384657',
#     'ext1': '',
#     'ext2': 'gn:comos-hfefkqr0818002:0',
#     'ext3': '',
#     'ext4': 'gn:comos-hfefkqr0818002:0',
#     'ext5': '原标题：英国政府称一直以台湾称呼台湾 反对航企修改标注\n[文/观察者网 张晨静]被中国民航局点名修改涉台标注的44家外航公司，已有多数公司作出了调整，其中包括英国航空。',
#     'old_level': '1',
#     'media_type': '',
#     'media_name': '观察者网'},
#    {'id': '1-1-35957248',
#     'column': 'gdxw1',
#     'title': '今年已有5位名将逝世 开国将星仅存16颗',
#     'url': 'http://news.sina.com.cn/o/2018-07-11/doc-ihfefkqq2214843.shtml',
#     'keywords': '授衔,逝世,将星',
#     'comment_channel': '',
#     'img': '',
#     'level': '0',
#     'createtime': '1531289205',
#     'ext1': '',
#     'ext2': 'gn:comos-hfefkqq2214843:0',
#     'ext3': '',
#     'ext4': 'gn:comos-hfefkqq2214843:0',
#     'ext5': '原标题：开国将星仅存16颗：今年已有5位名将逝世\n将星陨落。开国少将、原北京军区政委刘振华因病医治无效于2018年7月11日上午在北京逝世，享年97岁。目前，健在的开国将军目前尚存16人，他们基本都是在红军时期就参加革命，平均年龄已近百岁。',
#     'old_level': '2',
#     'media_type': '',
#     'media_name': '澎湃新闻'},
#    {'id': '1-1-35953072',
#     'column': 'gatxw',
#     'title': '三中案被起诉 马英九：没想到会在台风天下手',
#     'url': 'http://news.sina.com.cn/c/gat/2018-07-10/doc-ihfefkqp6950625.shtml',
#     'keywords': '马英九,三中,台风',
#     'comment_channel': 'gn',
#     'img': '',
#     'level': '0',
#     'createtime': '1531216911',
#     'ext1': '',
#     'ext2': 'gn:comos-hfefkqp6950625:0',
#     'ext3': '',
#     'ext4': 'gn:comos-hfefkqp6950625:0',
#     'ext5': '原标题：三中案被起诉 马英九：没想到会在台风天下手\n[观察者网综合报道]台湾省台北地检署10日上午侦结“三中案”，前台湾地区领导人马英九等6人被控主导贱卖国民党党产，都以涉特别背信罪起诉。对此，当事人马英九表示，被起诉早在预料之中，自己心情很平静，只是没想到他们会选择在台风天下手…',
#     'old_level': '2',
#     'media_type': '',
#     'media_name': '观察者网'},
#    {'id': '1-1-35951353',
#     'column': 'gatxw',
#     'title': '台教授：国民党大佬访陆是为重返执政做准备',
#     'url': 'http://news.sina.com.cn/c/gat/2018-07-10/doc-ihezpzwu7726769.shtml',
#     'keywords': '连战,选举,吴敦义,国民党',
#     'comment_channel': 'gn',
#     'img': '',
#     'level': '0',
#     'createtime': '1531207406',
#     'ext1': '',
#     'ext2': 'gn:comos-hezpzwu7726769:0',
#     'ext3': '',
#     'ext4': 'gn:comos-hezpzwu7726769:0',
#     'ext5': '原标题：台教授：国民党大佬访陆是为重返执政做准备\n[观察者网 综合报道]中评社7月10日报道，中国国民党前主席连战12日将率团前往大陆参访，并将在13日会晤大陆领导人，新竹交通大学通识教育中心副教授刘河北表示，国民党前主席吴伯雄、洪秀柱、连战纷访大陆，为2020国民党重返执政做准备，情况…',
#     'old_level': '2',
#     'media_type': '',
#     'media_name': '观察者网'},
#    {'id': '1-1-35948421',
#     'column': 'gdxw1',
#     'title': '人民日报揭虚假广告:商家片面求利益发布平台放水',
#     'url': 'http://news.sina.com.cn/o/2018-07-10/doc-ihezpzwu4357826.shtml',
#     'keywords': '防脱,虚假广告,广告',
#     'comment_channel': '',
#     'img': '',
#     'level': '0',
#     'createtime': '1531174108',
#     'ext1': '',
#     'ext2': 'gn:comos-hezpzwu4357826:0',
#     'ext3': '',
#     'ext4': 'gn:comos-hezpzwu4357826:0',
#     'ext5': '原标题：虚假广告为何屡禁不止（来信调查·关注诚信缺失问题③）\n“稳赚不赔，100%本息担保”“逢考必过，最权威的英语培训机构”“全网最低价”“彻底根治，绝不反弹”“用过都说好”……这些广告你是否耳熟能详？对此是否动过心？',
#     'old_level': '2',
#     'media_type': '',
#     'media_name': '人民网'},
#    {'id': '1-1-35946830',
#     'column': 'gatxw',
#     'title': '香港高校保录取是骗局?港大港中文：未与中介合作',
#     'url': 'http://news.sina.com.cn/o/2018-07-09/doc-ihezpzwu2792853.shtml',
#     'keywords': '骗局,招生,大港',
#     'comment_channel': '',
#     'img': '',
#     'level': '0',
#     'createtime': '1531138666',
#     'ext1': '',
#     'ext2': 'gn:comos-hezpzwu2792853:0',
#     'ext3': '',
#     'ext4': 'gn:comos-hezpzwu2792853:0',
#     'ext5': '原标题：香港高校“保录取”是骗局，港大港中文：从未与任何中介合作\n近日，全国各地高招录取工作正如火如荼进行。',
#     'old_level': '2',
#     'media_type': '',
#     'media_name': '澎湃新闻'},
#    {'id': '1-1-35945416',
#     'column': 'gatxw',
#     'title': '台军将采购上百辆美式M1A2 称其“地表最强坦克”',
#     'url': 'http://news.sina.com.cn/c/gat/2018-07-09/doc-ihezpzwu0355664.shtml',
#     'keywords': '国防部,台军,坦克',
#     'comment_channel': 'gn',
#     'img': '',
#     'level': '0',
#     'createtime': '1531117989',
#     'ext1': '',
#     'ext2': 'gn:comos-hezpzwu0355664:0',
#     'ext3': '',
#     'ext4': 'gn:comos-hezpzwu0355664:0',
#     'ext5': '原标题：台军将采购上百辆M1A2 称其“地表最强坦克”\n[观察者网 综合报道]据台媒7月9日报道，台军是否采购新坦克，在台军方内部反反复复讨论了10多年，如今终于定案。台军官员证实，台军采购新坦克的政策已经拍板，台湾将向美国采购M1A2坦克，“国防部”将于明年正式编列预算，蔡英文对此相当支…',
#     'old_level': '2',
#     'media_type': '',
#     'media_name': '观察者网'},
#    {'id': '1-1-35944976',
#     'column': 'gdxw1',
#     'title': '商务部研究员：史诗贸易战 不能指望三五个月解决',
#     'url': 'http://news.sina.com.cn/c/nd/2018-07-09/doc-ihezpzwt9846143.shtml',
#     'keywords': '贸易战,特朗普,史诗级,关税,内需',
#     'comment_channel': 'gn',
#     'img': '',
#     'level': '1',
#     'createtime': '1531113527',
#     'ext1': '',
#     'ext2': 'gn:comos-hezpzwt9846143:0',
#     'ext3': '',
#     'ext4': 'gn:comos-hezpzwt9846143:0',
#     'ext5': '原标题：史诗级贸易战，不能指望三五个月就解决\n从大国竞争视角看贸易战。',
#     'old_level': '1',
#     'media_type': '',
#     'media_name': '中国新闻网'}]}}

# %%
for ent in jd['result']['data']:
    print(ent['url'])
#jd['result']['data']
# Out:
# http://news.sina.com.cn/c/nd/2018-07-13/doc-ihfhfwmv0249311.shtml
# http://news.sina.com.cn/o/2018-07-13/doc-ihfhfwmv0226415.shtml
# http://news.sina.com.cn/c/gat/2018-07-13/doc-ihfhfwmu9092604.shtml
# http://news.sina.com.cn/c/nd/2018-07-13/doc-ihfhfwmu3378104.shtml
# http://news.sina.com.cn/c/nd/2018-07-13/doc-ihfhfwmu3223315.shtml
# http://news.sina.com.cn/c/nd/2018-07-13/doc-ihfhfwmu3154606.shtml
# http://news.sina.com.cn/c/2018-07-13/doc-ihfhfwmu2974994.shtml
# http://news.sina.com.cn/c/zs/2018-07-13/doc-ihfhfwmu2606271.shtml
# http://news.sina.com.cn/o/2018-07-13/doc-ihfefkqr3688372.shtml
# http://news.sina.com.cn/c/nd/2018-07-13/doc-ihfefkqr3653800.shtml
# http://news.sina.com.cn/w/2018-07-13/doc-ihfefkqr3593981.shtml
# http://news.sina.com.cn/o/2018-07-13/doc-ihfefkqr3570287.shtml
# http://news.sina.com.cn/o/2018-07-12/doc-ihfefkqr3371214.shtml
# http://news.sina.com.cn/c/nd/2018-07-13/doc-ihfefkqr2030117.shtml
# http://news.sina.com.cn/o/2018-07-12/doc-ihfefkqr0818002.shtml
# http://news.sina.com.cn/o/2018-07-11/doc-ihfefkqq2214843.shtml
# http://news.sina.com.cn/c/gat/2018-07-10/doc-ihfefkqp6950625.shtml
# http://news.sina.com.cn/c/gat/2018-07-10/doc-ihezpzwu7726769.shtml
# http://news.sina.com.cn/o/2018-07-10/doc-ihezpzwu4357826.shtml
# http://news.sina.com.cn/o/2018-07-09/doc-ihezpzwu2792853.shtml
# http://news.sina.com.cn/c/gat/2018-07-09/doc-ihezpzwu0355664.shtml
# http://news.sina.com.cn/c/nd/2018-07-09/doc-ihezpzwt9846143.shtml

# %%
def parseListLinks(url):
    newsdetails = []
    res = requests.get(url)
    jd= json.loads(res.text.lstrip('  newsloadercallback(').rstrip(');'))
    for ent in jd['result']['data']:
        newsdetails.append(getNewsDetail(ent['url']))
    return newsdetails

# %%
url = 'http://api.roll.news.sina.com.cn/zt_list?channel=news&cat_1=gnxw&cat_2==gdxw1||=gatxw||=zs-pl||=mtjj&level==1||=2&show_ext=1&show_all=1&show_num=22&tag=1&format=json&page=2&callback=newsloadercallback&_=1530023877286'
parseListLinks(url)
# Out:
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# [{'title': '资深机长：抽烟不是新闻 误关空调让同行笑掉大牙',
#   'newssource': '新浪新闻综合',
#   'dt': datetime.datetime(2018, 7, 13, 23, 3),
#   'article': '',
#   'editor': '霍宇昂 ',
#   'comments': 202},
#  {'title': '广州高校一对夫妻教员被同事杀死 嫌疑人被批捕',
#   'newssource': '中国新闻网',
#   'dt': datetime.datetime(2018, 7, 13, 22, 50),
#   'article': '',
#   'editor': '霍宇昂 ',
#   'comments': 238},
#  {'title': '蔡英文出行抗议随处见 台年轻人:我们的未来在哪?',
#   'newssource': '观察者网',
#   'dt': datetime.datetime(2018, 7, 13, 19, 8),
#   'article': '',
#   'editor': '余鹏飞 ',
#   'comments': 11},
#  {'title': '北京市长陈吉宁会见美国特斯拉公司董事长马斯克',
#   'newssource': '新浪新闻综合',
#   'dt': datetime.datetime(2018, 7, 13, 6, 34),
#   'article': '',
#   'editor': '霍宇昂 ',
#   'comments': 18},
#  {'title': '人民日报望海楼：荒谬的药方治不了美国的病',
#   'newssource': '人民日报海外版',
#   'dt': datetime.datetime(2018, 7, 13, 5, 35),
#   'article': '',
#   'editor': '霍宇昂 ',
#   'comments': 51},
#  {'title': '中国商务部突然发的这篇声明 传递了一个核心信息',
#   'newssource': '新浪新闻综合',
#   'dt': datetime.datetime(2018, 7, 13, 5, 4),
#   'article': '',
#   'editor': '霍宇昂 ',
#   'comments': 651},
#  {'title': '黑龙江省长谈小煤矿整治:是干部忠诚担当的试金石',
#   'newssource': '人民日报',
#   'dt': datetime.datetime(2018, 7, 13, 3, 53),
#   'article': '',
#   'editor': '霍宇昂 ',
#   'comments': 55},
#  {'title': '新京报谈教授兼职被控贪污案反转:重公正而非成就',
#   'newssource': '新京报',
#   'dt': datetime.datetime(2018, 7, 13, 1, 39),
#   'article': '',
#   'editor': '张岩 ',
#   'comments': 0},
#  {'title': '驻韩美军将用以干预南海?美探索半岛驻军任务转型',
#   'newssource': '参考消息',
#   'dt': datetime.datetime(2018, 7, 13, 0, 44),
#   'article': '',
#   'editor': '霍宇昂 ',
#   'comments': 25},
#  {'title': '有力回击美国政府的不实指控 商务部可以这样做',
#   'newssource': '环球网',
#   'dt': datetime.datetime(2018, 7, 13, 0, 29),
#   'article': '',
#   'editor': '霍宇昂 ',
#   'comments': 195},
#  {'title': '英媒：马来西亚高官或本周访华 重谈四大项目合同',
#   'newssource': '参考消息',
#   'dt': datetime.datetime(2018, 7, 13, 0, 19),
#   'article': '',
#   'editor': '霍宇昂 ',
#   'comments': 744},
#  {'title': '“老肉”回锅胜算高？外媒称台地方选举机关算尽',
#   'newssource': '参考消息',
#   'dt': datetime.datetime(2018, 7, 13, 0, 19),
#   'article': '',
#   'editor': '霍宇昂 ',
#   'comments': 0},
#  {'title': '人民日报：美国不应将世界经济拖入“衰退陷阱”',
#   'newssource': '人民日报',
#   'dt': datetime.datetime(2018, 7, 12, 23, 20),
#   'article': '',
#   'editor': '霍宇昂 ',
#   'comments': 603},
#  {'title': '中国病理学泰斗去世 诊断曾被誉为“全国金标准”',
#   'newssource': '人民日报',
#   'dt': datetime.datetime(2018, 7, 12, 19, 3),
#   'article': '',
#   'editor': '霍宇昂 ',
#   'comments': 2102},
#  {'title': '英政府:一直以“台湾”称呼台湾 反对航企改标注',
#   'newssource': '观察者网',
#   'dt': datetime.datetime(2018, 7, 12, 16, 34),
#   'article': '',
#   'editor': '余鹏飞 ',
#   'comments': 5126},
#  {'title': '今年已有5位名将逝世 开国将星仅存16颗',
#   'newssource': '澎湃新闻',
#   'dt': datetime.datetime(2018, 7, 11, 14, 4),
#   'article': '',
#   'editor': '乔雷华 SN098',
#   'comments': 2},
#  {'title': '三中案被起诉 马英九：没想到会在台风天下手',
#   'newssource': '观察者网',
#   'dt': datetime.datetime(2018, 7, 10, 17, 56),
#   'article': '',
#   'editor': '余鹏飞 ',
#   'comments': 0},
#  {'title': '台教授：国民党大佬访陆是为重返执政做准备',
#   'newssource': '观察者网',
#   'dt': datetime.datetime(2018, 7, 10, 15, 0),
#   'article': '',
#   'editor': '余鹏飞 ',
#   'comments': 203},
#  {'title': '人民日报揭虚假广告:商家片面求利益发布平台放水',
#   'newssource': '人民网',
#   'dt': datetime.datetime(2018, 7, 10, 4, 45),
#   'article': '',
#   'editor': '乔雷华 SN098',
#   'comments': 3},
#  {'title': '香港高校保录取是骗局?港大港中文：未与中介合作',
#   'newssource': '澎湃新闻',
#   'dt': datetime.datetime(2018, 7, 9, 20, 12),
#   'article': '',
#   'editor': '余鹏飞 ',
#   'comments': 3},
#  {'title': '台军将采购上百辆美式M1A2 称其“地表最强坦克”',
#   'newssource': '观察者网',
#   'dt': datetime.datetime(2018, 7, 9, 14, 23),
#   'article': '',
#   'editor': '余鹏飞 ',
#   'comments': 17},
#  {'title': '商务部研究员：史诗贸易战 不能指望三五个月解决',
#   'newssource': '中国新闻网',
#   'dt': datetime.datetime(2018, 7, 9, 13, 15),
#   'article': '',
#   'editor': '霍宇昂 ',
#   'comments': 532}]

# %%
url ='http://api.roll.news.sina.com.cn/zt_list?channel=news&cat_1=gnxw&cat_2==gdxw1||=gatxw||=zs-pl||=mtjj&level==1||=2&show_ext=1&show_all=1&show_num=22&tag=1&format=json&page={}&callback=newsloadercallback&_=1530023877286'
for i in range(1,10):
    newsurl = url.format(i)
    print(newsurl)
# Out:
# http://api.roll.news.sina.com.cn/zt_list?channel=news&cat_1=gnxw&cat_2==gdxw1||=gatxw||=zs-pl||=mtjj&level==1||=2&show_ext=1&show_all=1&show_num=22&tag=1&format=json&page=1&callback=newsloadercallback&_=1530023877286
# http://api.roll.news.sina.com.cn/zt_list?channel=news&cat_1=gnxw&cat_2==gdxw1||=gatxw||=zs-pl||=mtjj&level==1||=2&show_ext=1&show_all=1&show_num=22&tag=1&format=json&page=2&callback=newsloadercallback&_=1530023877286
# http://api.roll.news.sina.com.cn/zt_list?channel=news&cat_1=gnxw&cat_2==gdxw1||=gatxw||=zs-pl||=mtjj&level==1||=2&show_ext=1&show_all=1&show_num=22&tag=1&format=json&page=3&callback=newsloadercallback&_=1530023877286
# http://api.roll.news.sina.com.cn/zt_list?channel=news&cat_1=gnxw&cat_2==gdxw1||=gatxw||=zs-pl||=mtjj&level==1||=2&show_ext=1&show_all=1&show_num=22&tag=1&format=json&page=4&callback=newsloadercallback&_=1530023877286
# http://api.roll.news.sina.com.cn/zt_list?channel=news&cat_1=gnxw&cat_2==gdxw1||=gatxw||=zs-pl||=mtjj&level==1||=2&show_ext=1&show_all=1&show_num=22&tag=1&format=json&page=5&callback=newsloadercallback&_=1530023877286
# http://api.roll.news.sina.com.cn/zt_list?channel=news&cat_1=gnxw&cat_2==gdxw1||=gatxw||=zs-pl||=mtjj&level==1||=2&show_ext=1&show_all=1&show_num=22&tag=1&format=json&page=6&callback=newsloadercallback&_=1530023877286
# http://api.roll.news.sina.com.cn/zt_list?channel=news&cat_1=gnxw&cat_2==gdxw1||=gatxw||=zs-pl||=mtjj&level==1||=2&show_ext=1&show_all=1&show_num=22&tag=1&format=json&page=7&callback=newsloadercallback&_=1530023877286
# http://api.roll.news.sina.com.cn/zt_list?channel=news&cat_1=gnxw&cat_2==gdxw1||=gatxw||=zs-pl||=mtjj&level==1||=2&show_ext=1&show_all=1&show_num=22&tag=1&format=json&page=8&callback=newsloadercallback&_=1530023877286
# http://api.roll.news.sina.com.cn/zt_list?channel=news&cat_1=gnxw&cat_2==gdxw1||=gatxw||=zs-pl||=mtjj&level==1||=2&show_ext=1&show_all=1&show_num=22&tag=1&format=json&page=9&callback=newsloadercallback&_=1530023877286

# %%
url ='http://api.roll.news.sina.com.cn/zt_list?channel=news&cat_1=gnxw&cat_2==gdxw1||=gatxw||=zs-pl||=mtjj&level==1||=2&show_ext=1&show_all=1&show_num=22&tag=1&format=json&page={}&callback=newsloadercallback&_=1530023877286'
news_total =[]
for i in range(1,3):
    newsurl = url.format(i)
    newsary = parseListLinks(newsurl)
    news_total.extend(newsary)
# Out:
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# ---------------------------------------------------------------------------
# TimeoutError                              Traceback (most recent call last)
# E:\programmer_software\Anaconda\lib\site-packages\urllib3\connection.py in _new_conn(self)
#     140             conn = connection.create_connection(
# --> 141                 (self.host, self.port), self.timeout, **extra_kw)
#     142
#
# E:\programmer_software\Anaconda\lib\site-packages\urllib3\util\connection.py in create_connection(address, timeout, source_address, socket_options)
#      82     if err is not None:
# ---> 83         raise err
#      84
#
# E:\programmer_software\Anaconda\lib\site-packages\urllib3\util\connection.py in create_connection(address, timeout, source_address, socket_options)
#      72                 sock.bind(source_address)
# ---> 73             sock.connect(sa)
#      74             return sock
#
# TimeoutError: [WinError 10060] 由于连接方在一段时间后没有正确答复或连接的主机没有反应，连接尝试失败。
#
# During handling of the above exception, another exception occurred:
#
# NewConnectionError                        Traceback (most recent call last)
# E:\programmer_software\Anaconda\lib\site-packages\urllib3\connectionpool.py in urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, **response_kw)
#     600                                                   body=body, headers=headers,
# --> 601                                                   chunked=chunked)
#     602
#
# E:\programmer_software\Anaconda\lib\site-packages\urllib3\connectionpool.py in _make_request(self, conn, method, url, timeout, chunked, **httplib_request_kw)
#     356         else:
# --> 357             conn.request(method, url, **httplib_request_kw)
#     358
#
# E:\programmer_software\Anaconda\lib\http\client.py in request(self, method, url, body, headers, encode_chunked)
#    1238         """Send a complete request to the server."""
# -> 1239         self._send_request(method, url, body, headers, encode_chunked)
#    1240
#
# E:\programmer_software\Anaconda\lib\http\client.py in _send_request(self, method, url, body, headers, encode_chunked)
#    1284             body = _encode(body, 'body')
# -> 1285         self.endheaders(body, encode_chunked=encode_chunked)
#    1286
#
# E:\programmer_software\Anaconda\lib\http\client.py in endheaders(self, message_body, encode_chunked)
#    1233             raise CannotSendHeader()
# -> 1234         self._send_output(message_body, encode_chunked=encode_chunked)
#    1235
#
# E:\programmer_software\Anaconda\lib\http\client.py in _send_output(self, message_body, encode_chunked)
#    1025         del self._buffer[:]
# -> 1026         self.send(msg)
#    1027
#
# E:\programmer_software\Anaconda\lib\http\client.py in send(self, data)
#     963             if self.auto_open:
# --> 964                 self.connect()
#     965             else:
#
# E:\programmer_software\Anaconda\lib\site-packages\urllib3\connection.py in connect(self)
#     165     def connect(self):
# --> 166         conn = self._new_conn()
#     167         self._prepare_conn(conn)
#
# E:\programmer_software\Anaconda\lib\site-packages\urllib3\connection.py in _new_conn(self)
#     149             raise NewConnectionError(
# --> 150                 self, "Failed to establish a new connection: %s" % e)
#     151
#
# NewConnectionError: <urllib3.connection.HTTPConnection object at 0x0000000008605A90>: Failed to establish a new connection: [WinError 10060] 由于连接方在一段时间后没有正确答复或连接的主机没有反应，连接尝试失败。
#
# During handling of the above exception, another exception occurred:
#
# MaxRetryError                             Traceback (most recent call last)
# E:\programmer_software\Anaconda\lib\site-packages\requests\adapters.py in send(self, request, stream, timeout, verify, cert, proxies)
#     439                     retries=self.max_retries,
# --> 440                     timeout=timeout
#     441                 )
#
# E:\programmer_software\Anaconda\lib\site-packages\urllib3\connectionpool.py in urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, **response_kw)
#     638             retries = retries.increment(method, url, error=e, _pool=self,
# --> 639                                         _stacktrace=sys.exc_info()[2])
#     640             retries.sleep()
#
# E:\programmer_software\Anaconda\lib\site-packages\urllib3\util\retry.py in increment(self, method, url, response, error, _pool, _stacktrace)
#     387         if new_retry.is_exhausted():
# --> 388             raise MaxRetryError(_pool, url, error or ResponseError(cause))
#     389
#
# MaxRetryError: HTTPConnectionPool(host='news.sina.com.cn', port=80): Max retries exceeded with url: /o/2018-07-12/doc-ihfefkqr0818002.shtml (Caused by NewConnectionError('<urllib3.connection.HTTPConnection object at 0x0000000008605A90>: Failed to establish a new connection: [WinError 10060] 由于连接方在一段时间后没有正确答复或连接的主机没有反应，连接尝试失败。',))
#
# During handling of the above exception, another exception occurred:
#
# ConnectionError                           Traceback (most recent call last)
# <ipython-input-21-8657a83b4f0d> in <module>()
#       3 for i in range(1,3):
#       4     newsurl = url.format(i)
# ----> 5     newsary = parseListLinks(newsurl)
#       6     news_total.extend(newsary)
#
# <ipython-input-18-6d38462bc011> in parseListLinks(url)
#       4     jd= json.loads(res.text.lstrip('  newsloadercallback(').rstrip(');'))
#       5     for ent in jd['result']['data']:
# ----> 6         newsdetails.append(getNewsDetail(ent['url']))
#       7     return newsdetails
#
# <ipython-input-14-699cd6091f39> in getNewsDetail(newsurl)
#       4 def getNewsDetail(newsurl):
#       5     result={}
# ----> 6     res = requests.get(newsurl)
#       7     res.encoding ='utf-8'
#       8     soup =BeautifulSoup(res.text,'html.parser')
#
# E:\programmer_software\Anaconda\lib\site-packages\requests\api.py in get(url, params, **kwargs)
#      70
#      71     kwargs.setdefault('allow_redirects', True)
# ---> 72     return request('get', url, params=params, **kwargs)
#      73
#      74
#
# E:\programmer_software\Anaconda\lib\site-packages\requests\api.py in request(method, url, **kwargs)
#      56     # cases, and look like a memory leak in others.
#      57     with sessions.Session() as session:
# ---> 58         return session.request(method=method, url=url, **kwargs)
#      59
#      60
#
# E:\programmer_software\Anaconda\lib\site-packages\requests\sessions.py in request(self, method, url, params, data, headers, cookies, files, auth, timeout, allow_redirects, proxies, hooks, stream, verify, cert, json)
#     506         }
#     507         send_kwargs.update(settings)
# --> 508         resp = self.send(prep, **send_kwargs)
#     509
#     510         return resp
#
# E:\programmer_software\Anaconda\lib\site-packages\requests\sessions.py in send(self, request, **kwargs)
#     616
#     617         # Send the request
# --> 618         r = adapter.send(request, **kwargs)
#     619
#     620         # Total elapsed time of the request (approximately)
#
# E:\programmer_software\Anaconda\lib\site-packages\requests\adapters.py in send(self, request, stream, timeout, verify, cert, proxies)
#     506                 raise SSLError(e, request=request)
#     507
# --> 508             raise ConnectionError(e, request=request)
#     509
#     510         except ClosedPoolError as e:
#
# ConnectionError: HTTPConnectionPool(host='news.sina.com.cn', port=80): Max retries exceeded with url: /o/2018-07-12/doc-ihfefkqr0818002.shtml (Caused by NewConnectionError('<urllib3.connection.HTTPConnection object at 0x0000000008605A90>: Failed to establish a new connection: [WinError 10060] 由于连接方在一段时间后没有正确答复或连接的主机没有反应，连接尝试失败。',))

# %%
#查看新闻总数
len(news_total)

# %%
#导入pandas，将数据以excel表格输出
import pandas
df = pandas.DataFrame(news_total)
df

# %%
df.to_excel('new.xlsx')

# %%
import sqlite3
with sqlite3.connect('new.sqlite') as db:
    df.to_sql('new',con =db)

# %%
import sqlite3
with sqlite3.connect('new.sqlite') as db:
    df2 =pandas.read_sql_query('select * from new',con =db)

# %%
df2
